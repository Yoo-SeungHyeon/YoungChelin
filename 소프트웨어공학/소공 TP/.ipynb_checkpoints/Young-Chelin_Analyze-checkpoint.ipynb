# %%
import pandas as pd
import numpy as np
import random
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import scipy as sp
import scipy.stats
import pymysql

# %% [markdown]
# ## 평가 데이터 가져오기

# %%
# Mysql에서 데이터 가져오는 함수
def get_mysql_data(str):
    conn = pymysql.connect(host = "localhost",
             user= "root", password = "1234", charset = "utf8")
    cursor = conn.cursor()
    cursor.execute(str)
    data = cursor.fetchall()
    return data

# %%
# 데이터의 columns_name을 지정함
Raw_df = pd.DataFrame(columns=['menu_id','time', 'user_name', 'deaning', 'couple',
                'drink', 'family','friend', 'number', 'plating', 'price', 
                'restaurant_id', 'service', 'solo','flavor','url','id'], data = get_mysql_data("select * from young_cheline.evaluate"))
Raw_df.head()
# Out:
#    menu_id        time    user_name deaning couple drink family friend  \
# 0        1  2023-12-07  0045b6f3-8a    None      0  None   None   None
# 1        1  2023-12-07  0047390f-82       1   None  None   None      4
# 2        1  2023-12-07  004a7141-85       2   None     3   None   None
# 3        1  2023-12-07  004ab9f1-86    None   None  None      1   None
# 4        1  2023-12-07  005a45fe-34       1      0  None   None   None
#
#    number plating price restaurant_id service  solo flavor  \
# 0    6633    None     3    1883770159       2  None      1
# 1   54530       1     1    1883770159       3  None      2
# 2   31235       1  None    1883770159       2  None      2
# 3   33625       2     1    1883770159       1  None      1
# 4   57206       3     1    1883770159    None  None      2
#
#                                                  url  id
# 0  https://youngcheline.s3.ap-northeast-2.amazona...   4
# 1  https://youngcheline.s3.ap-northeast-2.amazona...   8
# 2  https://youngcheline.s3.ap-northeast-2.amazona...   5
# 3  https://youngcheline.s3.ap-northeast-2.amazona...   4
# 4  https://youngcheline.s3.ap-northeast-2.amazona...   4

# %%
user_df = pd.DataFrame(columns = ['id','active','email','password','role','temp_pw','time','user_name'],data = get_mysql_data("select * from young_cheline.user"))
user_df = user_df[user_df['user_name'].notnull()]
user_df.head()
# Out:
#    id   active       email                                           password  \
# 0   3  b'\x01'  92f8a6bc-c  $2a$10$yG8.Xpcd91BzO0z2zJSwguOih3emckrD.Ouga5R...
# 1   4  b'\x01'  7ce5f453-e  $2a$10$Ge8tRj4hwT1vv.MIkMYqeuKZYrBPxlJG0haZqm0...
# 2   5  b'\x01'  48d7bd60-3  $2a$10$IlTwPARUqUDZYex68XCvh.pZAxaHmc4jppo9N.J...
# 3   6  b'\x01'  51e62ad4-a  $2a$10$yHdM/J1cL1/qik8MKfo/X.dQAVRWNINvXAmT9lJ...
# 4   7  b'\x01'  0fed065c-0  $2a$10$tVljIbO6PHRwhPMhGYHABuih.aidkf6X90vl/lK...
#
#    role temp_pw time    user_name
# 0  None    None  NaT  00c04056-58
# 1  None    None  NaT  7c12ec6e-98
# 2  None    None  NaT  939396d1-ca
# 3  None    None  NaT  466dcd86-93
# 4  None    None  NaT  449874b1-94

# %%
menu_df = pd.DataFrame(columns = ['menu_id','menu_name','restaurant_id','url'], data = get_mysql_data('SELECT * FROM young_cheline.menu'))
menu_df.head()
# Out:
#    menu_id menu_name restaurant_id  \
# 0        1      대창덮밥    1883770159
# 1        2       뚝배기      15752650
# 2        3    꿀갈비비빔밥     714569417
# 3        4      돼지국밥      11385265
# 4        5       삼겹살     287757696
#
#                                                  url
# 0  https://youngcheline.s3.ap-northeast-2.amazona...
# 1  https://youngcheline.s3.ap-northeast-2.amazona...
# 2  https://youngcheline.s3.ap-northeast-2.amazona...
# 3  https://youngcheline.s3.ap-northeast-2.amazona...
# 4  https://youngcheline.s3.ap-northeast-2.amazona...

# %% [raw]
# datalist = []
# for i in range(34):
#     datalist.append(menu_df.iloc[i,:].tolist() + random.choices(range(9,15), k = 2) + random.choices(range(5,10), k = 1)+ random.choices(range(1,6),k=1))
# pra_menu_df = pd.DataFrame(columns = ['menu_id','menu_name','restaurant_id','url','1','2','3','4'],data = datalist)

# %% [raw]
# pra_menu_df.head(5)

# %% [raw]
# a = pra_menu_df.iloc[0][4:8]
# pro = np.array([int(a) for a in pra_menu_df.iloc[0][4:8]])
# sum = np.sum(pro)
# proba = pro/sum

# %% [raw]
# proba

# %% [raw]
# def Random_Sample(df,n):
#     df_num = len(df)
#     user_id = id
#     sample_data = []
#     for i in range(n):
#         number = [1,2,3,4]
#         random_index = random.randrange(df_num)
#         menu_info = df.iloc[random_index][0:4]
#         prob = np.array([int(a) for a in df.iloc[random_index].loc['1','2','3','4']])
#         sum = np.sum(prob)
#         proba = prob/sum
#         taste = np.random.choice(number,p = proba)
#         sample_data.append([menu_info[0],menu_info[1],menu_info[2],menu_info[3],taste])
#     return pd.DataFrame(columns= ['menu_id','menu_name','restaurant_id','url','taste'], data = sample_data)

# %% [raw]
# sample_df = Random_Sample(pra_menu_df,10000)

# %% [raw]
# sample_df.head()

# %% [raw]
# smd = sample_df[sample_df['menu_id'] == 7]

# %% [raw]
# #smd

# %% [raw]
# display(len(smd[smd['taste']==1]),len(smd[smd['taste']==2]),len(smd[smd['taste']==3]),len(smd[smd['taste']==4]))

# %% [raw]
# len(sample_df[sample_df['taste'] == 1])

# %% [raw]
# print('1 : ',len(sample_df[sample_df['taste'] == 1]),'2 : ',len(sample_df[sample_df['taste'] == 2]),'3 : ',len(sample_df[sample_df['taste'] == 3]),'4 : ',len(sample_df[sample_df['taste'] == 4]))

# %% [raw]
# menu_info = pra_menu_df.iloc[0][0:4].tolist()

# %% [raw]
# menu_info

# %% [raw]
# menu_info[3]

# %% [raw]
# df = pra_menu_df
# n = 1
# ##---------------------------------
# df_num = len(df)
# sample_data = []
# for i in range(n):
#     number = [1,2,3,4]
#     random_index = random.randrange(df_num)
#     menu_info = df.iloc[random_index][0:4].tolist()
#
#     prob = np.array([int(a) for a in df.iloc[random_index][4:8]])
#     sum = np.sum(prob)
#
#
#     proba = prob/sum
#     taste = np.random.choice(number,p= proba)
#     #    sample_data.append([menu_info[0],menu_info[2],menu_info[3],menu_info[4],taste])
#     print(menu_info[0],'|',menu_info[1],'|',menu_info[2],'|',menu_info[3],'|',taste)

# %% [raw]
#     return pd.DataFrame(columns= ['menu_id','menu_name','restaurant_id','url','taste'], data = sample_data)

# %% [markdown]
# ## 데이터 전처리 [샘플데이터 추출, Null처리,피벗테이블]

# %%
user_df.head()
# Out:
#    id   active       email                                           password  \
# 0   3  b'\x01'  92f8a6bc-c  $2a$10$yG8.Xpcd91BzO0z2zJSwguOih3emckrD.Ouga5R...
# 1   4  b'\x01'  7ce5f453-e  $2a$10$Ge8tRj4hwT1vv.MIkMYqeuKZYrBPxlJG0haZqm0...
# 2   5  b'\x01'  48d7bd60-3  $2a$10$IlTwPARUqUDZYex68XCvh.pZAxaHmc4jppo9N.J...
# 3   6  b'\x01'  51e62ad4-a  $2a$10$yHdM/J1cL1/qik8MKfo/X.dQAVRWNINvXAmT9lJ...
# 4   7  b'\x01'  0fed065c-0  $2a$10$tVljIbO6PHRwhPMhGYHABuih.aidkf6X90vl/lK...
#
#    role temp_pw time    user_name
# 0  None    None  NaT  00c04056-58
# 1  None    None  NaT  7c12ec6e-98
# 2  None    None  NaT  939396d1-ca
# 3  None    None  NaT  466dcd86-93
# 4  None    None  NaT  449874b1-94

# %%
user_id = user_df.iloc[:,0].tolist()

# %% [raw]
# # 평가 데이터에서 가게이름과 메뉴이름, 맛을 랜덤으로 중복추출 하여 정규분포를 따르는 심플데이터 생성
# # 적은 데이터를 극복하기 위해 사용함.
# # 가게이름과 메뉴이름은 합쳐서 메뉴 아이디로 사용함
# def Normal_Random_Sample(df,id,n):
#     df_num = len(df)
#     rest_id = df.iloc[:,11].tolist()
#     menu_id = df.iloc[:,0].tolist()
#     mu = df.loc[:,'taste'].tolist()
#     extract = []
#     for i in range(n):
#         random_index = random.randrange(df_num)
#         mean = int(mu[random_index])
#         #rest = rest_id[random_index]
#         menu = menu_id[random_index]
#         user = id[random.randrange(10001)]
#         ran_taste = np.random.normal(mean,1,1)[0]
#         if ran_taste<0.5:
#             i = i-1
#             continue
#         else:
#             #extract.append([rest+str(menu),ran_taste,user])
#             extract.append([menu,ran_taste,user])
#
#     return pd.DataFrame(columns = ['menu_id', 'taste','user_id'], data = extract)

# %% [raw]
# # 임시로 100,000개의 데이터 생성해서 분석에 사용
# NRS_df = Normal_Random_Sample(Raw_df,user_id, 100000)

# %% [raw]
# # 임시 데이터 저장
# #NRS_df.to_csv('Normal_Random_Sample.csv')

# %% [raw]
# NRS_df

# %%
# 평가한 유저의 목록 가져오기
col_list = user_id
#list(set(NRS_df.iloc[:,2].tolist()))

# %%
NRS_df = pd.DataFrame(columns = ['menu_id','time','user_name','cleaning','couple','drink','family','friend','number','plating','price','restaurant_id','service','solo','flavor','url','id'], data = get_mysql_data('select * from young_cheline.evaluate'))

# %%
NRS_df.head()
# Out:
#    menu_id        time    user_name cleaning couple drink family friend  \
# 0        1  2023-12-07  0045b6f3-8a     None      0  None   None   None
# 1        1  2023-12-07  0047390f-82        1   None  None   None      4
# 2        1  2023-12-07  004a7141-85        2   None     3   None   None
# 3        1  2023-12-07  004ab9f1-86     None   None  None      1   None
# 4        1  2023-12-07  005a45fe-34        1      0  None   None   None
#
#    number plating price restaurant_id service  solo flavor  \
# 0    6633    None     3    1883770159       2  None      1
# 1   54530       1     1    1883770159       3  None      2
# 2   31235       1  None    1883770159       2  None      2
# 3   33625       2     1    1883770159       1  None      1
# 4   57206       3     1    1883770159    None  None      2
#
#                                                  url  id
# 0  https://youngcheline.s3.ap-northeast-2.amazona...   4
# 1  https://youngcheline.s3.ap-northeast-2.amazona...   8
# 2  https://youngcheline.s3.ap-northeast-2.amazona...   5
# 3  https://youngcheline.s3.ap-northeast-2.amazona...   4
# 4  https://youngcheline.s3.ap-northeast-2.amazona...   4

# %%
# 피벗테이블 생성
def make_ptable(df):
    ptable = df.pivot_table(values = 'flavor', index = 'menu_id', columns = 'user_name')
    
    return ptable

# %%
#피벗테이블로 데이터를 가공
menu_user=make_ptable(NRS_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '1' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 #피벗테이블로 데이터를 가공
# ----> 2 menu_user=make_ptable(NRS_df)
#
# Cell In[35], line 3, in make_ptable(df)
#       2 def make_ptable(df):
# ----> 3     ptable = df.pivot_table(values = 'flavor', index = 'menu_id', columns = 'user_name')
#       5     return ptable
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9193, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9176 @Substitution("")
#    9177 @Appender(_shared_docs["pivot_table"])
#    9178 def pivot_table(
#    (...)
#    9189     sort: bool = True,
#    9190 ) -> DataFrame:
#    9191     from pandas.core.reshape.pivot import pivot_table
# -> 9193     return pivot_table(
#    9194         self,
#    9195         values=values,
#    9196         index=index,
#    9197         columns=columns,
#    9198         aggfunc=aggfunc,
#    9199         fill_value=fill_value,
#    9200         margins=margins,
#    9201         dropna=dropna,
#    9202         margins_name=margins_name,
#    9203         observed=observed,
#    9204         sort=sort,
#    9205     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:99, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      96     table = concat(pieces, keys=keys, axis=1)
#      97     return table.__finalize__(data, method="pivot_table")
# ---> 99 table = __internal_pivot_table(
#     100     data,
#     101     values,
#     102     index,
#     103     columns,
#     104     aggfunc,
#     105     fill_value,
#     106     margins,
#     107     dropna,
#     108     margins_name,
#     109     observed,
#     110     sort,
#     111 )
#     112 return table.__finalize__(data, method="pivot_table")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:169, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     166     values = list(values)
#     168 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
# --> 169 agged = grouped.agg(aggfunc)
#     171 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     172     agged = agged.dropna(how="all")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1442, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1439     kwargs["engine_kwargs"] = engine_kwargs
#    1441 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1442 result = op.agg()
#    1443 if not is_dict_like(func) and result is not None:
#    1444     # GH #52849
#    1445     if not self.as_index and is_list_like(func):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:172, in Apply.agg(self)
#     169 kwargs = self.kwargs
#     171 if isinstance(func, str):
# --> 172     return self.apply_str()
#     174 if is_dict_like(func):
#     175     return self.agg_dict_like()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:586, in Apply.apply_str(self)
#     584         else:
#     585             self.kwargs["axis"] = self.axis
# --> 586 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:669, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     667 f = getattr(obj, func)
#     668 if callable(f):
# --> 669     return f(*args, **kwargs)
#     671 # people may aggregate on a non-callable attribute
#     672 # but don't let them think they can pass args to it
#     673 assert len(args) == 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
menu_id = menu_user.index.to_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 menu_id = menu_user.index.to_list()
#
# NameError: name 'menu_user' is not defined

# %%
 #0으로 채우기
temp=menu_user.fillna(0)

# %% [markdown]
# ## 코사인 유사도로 추천 목록 만들기

# %%
# #코사인 유사도 구하기
cos=cosine_similarity(temp)
cos=pd.DataFrame(data=cos, index=menu_id,columns=menu_id)

# %%
# 코사인 유사도로 판별된 추천할만한 목록 10개 출력 함수
def recomand(user_id):
    ex = menu_user.assign(menu=menu_id)
    user_menu=ex.loc[ex[user_id].notnull(), [user_id, 'menu']]
    user_cos=cos[user_menu['menu']]
    user_cos=user_cos[~user_cos.isin(user_cos.loc[user_menu['menu']])].dropna()
    X_vector = user_menu.iloc[:,[0]].values/7+1
    Y_matrix= user_cos.to_numpy()
    Matrix_product=Y_matrix.dot(X_vector)
    user_cos['Sum']=Matrix_product
    user_recomand=user_cos.sort_values('Sum',ascending=False).head(10).index.to_list()
    return user_recomand

# %%
#모든 사용자의 추천 목록을 받아오는 코드
#for i in col_list:
#    A = recomand(i)
#    print(A)

#한명의 추천 목록을 받아오는 테스트 코드
A = recomand(col_list[0])
print(A)
# Out:
# [8, 22, 32, 12, 10, 7, 13, 9, 2, 14]

# %% [markdown]
# ---

# %%
#샘플 데이터의 데이터프레임
NRS_df
# Out:
#        menu_id     taste  user_id
# 0            4  2.232396     2877
# 1           29  1.796913      324
# 2           12  2.283797      776
# 3           15  1.917218      433
# 4           16  1.116345     1635
# ...        ...       ...      ...
# 81112       11  1.279146     1522
# 81113        9  4.762271     2811
# 81114        8  4.555340     6602
# 81115        2  1.193357     8568
# 81116        7  3.525815     6147
#
# [81117 rows x 3 columns]

# %%
#위에서 피벗테이블 만들 때 생성한 menu_id목록 가져오기
menu_id_list = list(set(NRS_df.iloc[:,0].tolist()))
#menu_id_list = menu_id

# %% [raw]
# NRS_df[NRS_df.iloc[:,0] == target].describe()

# %%
# 메뉴의 평균을 구해서 데이터프레임으로 생성
df_list = []
for i in range(len(menu_id_list)):
    target = menu_id_list[i]
    target_mean = NRS_df[NRS_df.iloc[:,0] == target].describe().iloc[1,1]
    df_list.append([target, target_mean])
menu_taste_mean = pd.DataFrame(columns = ['menu_id','mean'], data = df_list)

# %%
menu_taste_mean.sort_values('menu_id')
# Out:
#     menu_id          mean
# 0         1  50032.435579
# 1         2  49814.520914
# 2         3  50037.302480
# 3         4  49913.671694
# 4         5  49751.885395
# 5         6  50170.441036
# 6         7  50127.908192
# 7         8  49791.220333
# 8         9  49401.063890
# 9        10  50579.028011
# 10       11  50023.309515
# 11       12  49874.049661
# 12       13  49242.059895
# 13       14  49216.555936
# 14       15  50392.558342
# 15       16  50422.185071
# 16       17  49402.220717
# 17       18  49777.377385
# 18       19  49619.411660
# 19       20  49605.123496
# 20       21  50375.017591
# 21       22  49219.325397
# 22       23  50682.816485
# 23       24  50233.941885
# 24       25  50080.958927
# 25       26  50615.214609
# 26       27  49695.947001
# 27       28  49970.809052
# 28       29  50568.422792
# 29       30  50513.450877
# 30       31  50741.418353
# 31       32  50512.186867
# 32       33  50146.906936
# 33       34  49595.037857
# 34       35  49822.132176

# %%
menu_df = pd.DataFrame(columns = ['menu_id','menu_name','restaurant_id','url'],data = get_mysql_data("SELECT * FROM young_cheline.menu;"))

# %%
menu_df.head()
# Out:
#    menu_id menu_name restaurant_id  \
# 0        1      대창덮밥    1883770159
# 1        2       뚝배기      15752650
# 2        3    꿀갈비비빔밥     714569417
# 3        4      돼지국밥      11385265
# 4        5       삼겹살     287757696
#
#                                                  url
# 0  https://youngcheline.s3.ap-northeast-2.amazona...
# 1  https://youngcheline.s3.ap-northeast-2.amazona...
# 2  https://youngcheline.s3.ap-northeast-2.amazona...
# 3  https://youngcheline.s3.ap-northeast-2.amazona...
# 4  https://youngcheline.s3.ap-northeast-2.amazona...

# %%
menu_taste_mean.set_index('menu_id',inplace=True)

# %%
menu_df.set_index('menu_id',inplace = True)

# %%
menu_df.join(menu_taste_mean)
# Out:
#          menu_name restaurant_id  \
# menu_id
# 1             대창덮밥    1883770159
# 2              뚝배기      15752650
# 3           꿀갈비비빔밥     714569417
# 4             돼지국밥      11385265
# 5              삼겹살     287757696
# 6            치즈돈까스     392495073
# 7              돈까스     392495073
# 8           차돌된장찌개      10306127
# 9          김치말이냉국수     434788818
# 10             몽짬뽕      20638851
# 11              육회    1258680088
# 12           손시스시A      27407049
# 13           항정살덮밥      27407036
# 14        상하이크림파스타      27407036
# 15             영남동     444340519
# 16             뒷고기      14541884
# 17             볶음밥    1566612864
# 18       누텔라 아이스크림     226916996
# 19            마라전골     143343585
# 20             칼국수     880781940
# 21          매콤크림우동     983114429
# 22            제육볶음      11300334
# 23          샐러드파스타     746623517
# 24            돈돈까스    2020305821
# 25           등심돈까스    2020305821
# 26           안심돈까스    2020305821
# 27            타이짬뽕      26353366
# 28          목살플레이트    1956466361
# 29           로제떡볶이    1032781993
# 30              갈비    1323716207
# 31          후라이드치킨     277055458
# 32            황금찜닭     777963780
# 33            가라아게    2084958402
# 34             갈비동      86660948
# 35           치즈돈까스    2020305821
#
#                                                        url          mean
# menu_id
# 1        https://youngcheline.s3.ap-northeast-2.amazona...  50032.435579
# 2        https://youngcheline.s3.ap-northeast-2.amazona...  49814.520914
# 3        https://youngcheline.s3.ap-northeast-2.amazona...  50037.302480
# 4        https://youngcheline.s3.ap-northeast-2.amazona...  49913.671694
# 5        https://youngcheline.s3.ap-northeast-2.amazona...  49751.885395
# 6        https://youngcheline.s3.ap-northeast-2.amazona...  50170.441036
# 7        https://youngcheline.s3.ap-northeast-2.amazona...  50127.908192
# 8        https://youngcheline.s3.ap-northeast-2.amazona...  49791.220333
# 9        https://youngcheline.s3.ap-northeast-2.amazona...  49401.063890
# 10       https://youngcheline.s3.ap-northeast-2.amazona...  50579.028011
# 11       https://youngcheline.s3.ap-northeast-2.amazona...  50023.309515
# 12       https://youngcheline.s3.ap-northeast-2.amazona...  49874.049661
# 13       https://youngcheline.s3.ap-northeast-2.amazona...  49242.059895
# 14       https://youngcheline.s3.ap-northeast-2.amazona...  49216.555936
# 15       https://youngcheline.s3.ap-northeast-2.amazona...  50392.558342
# 16       https://youngcheline.s3.ap-northeast-2.amazona...  50422.185071
# 17       https://youngcheline.s3.ap-northeast-2.amazona...  49402.220717
# 18       https://youngcheline.s3.ap-northeast-2.amazona...  49777.377385
# 19       https://youngcheline.s3.ap-northeast-2.amazona...  49619.411660
# 20       https://youngcheline.s3.ap-northeast-2.amazona...  49605.123496
# 21       https://youngcheline.s3.ap-northeast-2.amazona...  50375.017591
# 22       https://youngcheline.s3.ap-northeast-2.amazona...  49219.325397
# 23       https://youngcheline.s3.ap-northeast-2.amazona...  50682.816485
# 24       https://youngcheline.s3.ap-northeast-2.amazona...  50233.941885
# 25       https://youngcheline.s3.ap-northeast-2.amazona...  50080.958927
# 26       https://youngcheline.s3.ap-northeast-2.amazona...  50615.214609
# 27       https://youngcheline.s3.ap-northeast-2.amazona...  49695.947001
# 28       https://youngcheline.s3.ap-northeast-2.amazona...  49970.809052
# 29       https://youngcheline.s3.ap-northeast-2.amazona...  50568.422792
# 30       https://youngcheline.s3.ap-northeast-2.amazona...  50513.450877
# 31       https://youngcheline.s3.ap-northeast-2.amazona...  50741.418353
# 32       https://youngcheline.s3.ap-northeast-2.amazona...  50512.186867
# 33       https://youngcheline.s3.ap-northeast-2.amazona...  50146.906936
# 34       https://youngcheline.s3.ap-northeast-2.amazona...  49595.037857
# 35       https://youngcheline.s3.ap-northeast-2.amazona...  49822.132176

# %%
#피벗테이블을 가져와 계산을 편하게 한다.
p_table=make_ptable(NRS_df).transpose()

#데이터와 평균을 넣으면 데이터는 히스토그램으로, 평균은 수직선으로 표시해주는 함수
def histo_mean_graph(data,mean):
    plt.hist(data, alpha = 0.5 ,edgecolor='black')
    plt.axvline(mean, 0, 400, color='lightgreen', linestyle='--', linewidth=2)
    plt.show()

menu_mean_list = p_table.describe().iloc[1,:]

for i in range(len(menu_mean_list)):
    Data = p_table.iloc[:,i]
    Mean = menu_mean_list[i]
    histo_mean_graph(Data, Mean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '1' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 2
#       1 #피벗테이블을 가져와 계산을 편하게 한다.
# ----> 2 p_table=make_ptable(NRS_df).transpose()
#       4 #데이터와 평균을 넣으면 데이터는 히스토그램으로, 평균은 수직선으로 표시해주는 함수
#       5 def histo_mean_graph(data,mean):
#
# Cell In[35], line 3, in make_ptable(df)
#       2 def make_ptable(df):
# ----> 3     ptable = df.pivot_table(values = 'flavor', index = 'menu_id', columns = 'user_name')
#       5     return ptable
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9193, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9176 @Substitution("")
#    9177 @Appender(_shared_docs["pivot_table"])
#    9178 def pivot_table(
#    (...)
#    9189     sort: bool = True,
#    9190 ) -> DataFrame:
#    9191     from pandas.core.reshape.pivot import pivot_table
# -> 9193     return pivot_table(
#    9194         self,
#    9195         values=values,
#    9196         index=index,
#    9197         columns=columns,
#    9198         aggfunc=aggfunc,
#    9199         fill_value=fill_value,
#    9200         margins=margins,
#    9201         dropna=dropna,
#    9202         margins_name=margins_name,
#    9203         observed=observed,
#    9204         sort=sort,
#    9205     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:99, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      96     table = concat(pieces, keys=keys, axis=1)
#      97     return table.__finalize__(data, method="pivot_table")
# ---> 99 table = __internal_pivot_table(
#     100     data,
#     101     values,
#     102     index,
#     103     columns,
#     104     aggfunc,
#     105     fill_value,
#     106     margins,
#     107     dropna,
#     108     margins_name,
#     109     observed,
#     110     sort,
#     111 )
#     112 return table.__finalize__(data, method="pivot_table")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:169, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     166     values = list(values)
#     168 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
# --> 169 agged = grouped.agg(aggfunc)
#     171 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     172     agged = agged.dropna(how="all")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1442, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1439     kwargs["engine_kwargs"] = engine_kwargs
#    1441 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1442 result = op.agg()
#    1443 if not is_dict_like(func) and result is not None:
#    1444     # GH #52849
#    1445     if not self.as_index and is_list_like(func):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:172, in Apply.agg(self)
#     169 kwargs = self.kwargs
#     171 if isinstance(func, str):
# --> 172     return self.apply_str()
#     174 if is_dict_like(func):
#     175     return self.agg_dict_like()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:586, in Apply.apply_str(self)
#     584         else:
#     585             self.kwargs["axis"] = self.axis
# --> 586 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:669, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     667 f = getattr(obj, func)
#     668 if callable(f):
# --> 669     return f(*args, **kwargs)
#     671 # people may aggregate on a non-callable attribute
#     672 # but don't let them think they can pass args to it
#     673 assert len(args) == 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
x = np.arange(-4, 4, 0.01)
y = (lambda x: 1/np.sqrt(2*np.pi)/np.exp(x**2/2))(x)
plt.plot(x, y)
plt.show()

# %%
# 각 메뉴들의 평균을 계산한다.
p_table.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 # 각 메뉴들의 평균을 계산한다.
# ----> 2 p_table.describe()
#
# NameError: name 'p_table' is not defined

# %%
menu_taste_mean['mean']
# Out:
# menu_id
# 1     50032.435579
# 2     49814.520914
# 3     50037.302480
# 4     49913.671694
# 5     49751.885395
# 6     50170.441036
# 7     50127.908192
# 8     49791.220333
# 9     49401.063890
# 10    50579.028011
# 11    50023.309515
# 12    49874.049661
# 13    49242.059895
# 14    49216.555936
# 15    50392.558342
# 16    50422.185071
# 17    49402.220717
# 18    49777.377385
# 19    49619.411660
# 20    49605.123496
# 21    50375.017591
# 22    49219.325397
# 23    50682.816485
# 24    50233.941885
# 25    50080.958927
# 26    50615.214609
# 27    49695.947001
# 28    49970.809052
# 29    50568.422792
# 30    50513.450877
# 31    50741.418353
# 32    50512.186867
# 33    50146.906936
# 34    49595.037857
# 35    49822.132176
# Name: mean, dtype: float64

# %%
# 각 메뉴들의 평균들의 평균과 표준편차를 구해서 정규화에 사용한다.
menu_mean_list= menu_taste_mean['mean']
menu_mean_mean = menu_mean_list.mean()
menu_mean_std = menu_mean_list.std()

# %%
menu_mean_list
# Out:
# menu_id
# 1     50032.435579
# 2     49814.520914
# 3     50037.302480
# 4     49913.671694
# 5     49751.885395
# 6     50170.441036
# 7     50127.908192
# 8     49791.220333
# 9     49401.063890
# 10    50579.028011
# 11    50023.309515
# 12    49874.049661
# 13    49242.059895
# 14    49216.555936
# 15    50392.558342
# 16    50422.185071
# 17    49402.220717
# 18    49777.377385
# 19    49619.411660
# 20    49605.123496
# 21    50375.017591
# 22    49219.325397
# 23    50682.816485
# 24    50233.941885
# 25    50080.958927
# 26    50615.214609
# 27    49695.947001
# 28    49970.809052
# 29    50568.422792
# 30    50513.450877
# 31    50741.418353
# 32    50512.186867
# 33    50146.906936
# 34    49595.037857
# 35    49822.132176
# Name: mean, dtype: float64

# %%
# 메뉴별 맛의 평균 및 표준편차
print(menu_mean_mean, menu_mean_std)
# Out:
# 49999.08331446882 437.2002495004752

# %%
# 누적확률 계산을 위한 정규분포 세팅 
rv = sp.stats.norm(0,1)

# %%
# 메뉴가 몇 퍼센트의 음식인지 계산
menu_percent = 1-rv.cdf((menu_mean_list - menu_mean_mean)/menu_mean_std)

# %%
#계산한 퍼센트와 음식을 매칭시키는 함수
df_data = []
for i in range(len(menu_percent)):
    df_data.append(round(menu_percent[i]*100,3))

Percent_DeliFood_df = pd.DataFrame(columns = ['상위 N% 맛식'],data = df_data)

# %%
detail_df = menu_taste_mean.join(Percent_DeliFood_df)

# %%
detail_df.iloc[0].index
# Out:
# Index(['mean', '상위 N% 맛식'], dtype='object')

# %%
len(detail_df)
# Out:
# 35

# %%
type(detail_df.iloc[0].tolist()[1])
# Out:
# float

# %%
avg1 = detail_df.iloc[:,1].tolist()

# %%
avg2 = detail_df.iloc[:,0].tolist()

# %%
type(avg1)
# Out:
# list

# %%
# Out:
# float

# %%
conn = pymysql.connect(host = "localhost",
user= "root", password = "1234", charset = "utf8")
cursor = conn.cursor()

# %%
for i in range(34):
    cursor.execute(f'''INSERT INTO young_cheline.detail (menu_id,avg1,avg2) VALUE({i},{avg1[i]},{avg2[i]});''')

# %%
np.nan
# Out:
# nan

# %%
cursor.execute('''INSERT INTO young_cheline.detail (menu_id, ) VALUE();''',(i,detail_df.iloc[0].tolist()[0],detail_df.iloc[0].tolist()[1]))

# %%
conn.commit()

# %%
def get_menu_id():
    conn = pymysql.connect(host = "localhost",
             user= "root", password = "1234", charset = "utf8")
    cursor = conn.cursor()
    cursor.execute('''SELECT max(menu_id) FROM young_cheline.menu;''')
    menu_data = cursor.fetchall()
    menu_data = menu_data[0][0]
    return menu_data

# %%
def get_week_avg(menu_id):
    conn = pymysql.connect(host = "localhost",
        user= "root", password = "1234", charset = "utf8")
    cursor = conn.cursor()

    cursor.execute('''SELECT DATE_FORMAT(time, '%Y-%u') as week, menu_id, avg(flavor)
                FROM young_cheline.evaluate
                WHERE menu_id = {}
                GROUP BY week
                ORDER BY menu_id, week;'''.format(menu_id))
    
    data = cursor.fetchall()
    df = pd.DataFrame(data, columns=['time', 'menu_id', 'flavor'])

    return df

# %%
if __name__ == "__main__":
    range_menu = get_menu_id()

    for id in range(1,range_menu + 1):
        df = get_week_avg(id)
        print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[115], line 5
#       2 range_menu = get_menu_id()
#       4 for id in range(1,range_menu + 1):
# ----> 5     df = get_week_avg(id)
#       6     print(df)
#
# Cell In[114], line 6, in get_week_avg(menu_id)
#       2 conn = pymysql.connect(host = "localhost",
#       3     user= "root", password = "1234", charset = "utf8")
#       4 cursor = conn.cursor()
# ----> 6 cursor.execute('''SELECT DATE_FORMAT(time, '%Y-%u') as week, menu_id, avg(flavor)
#       7             FROM young_cheline.evaluate
#       8             WHERE menu_id = {}
#       9             GROUP BY week
#      10             ORDER BY menu_id, week;'''.format(menu_id))
#      12 data = cursor.fetchall()
#      13 df = pd.DataFrame(data, columns=['time', 'menu_id', 'flavor'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'flavor' in 'field list'")

# %%
def get_mean_taste():
    conn = pymysql.connect(host = "localhost",
                user= "root", password = "1234", charset = "utf8")
    cursor = conn.cursor()
    cursor.execute("select menu_id, restaurant_id,AVG(taste) from young_cheline.evaluate group by menu_id, restaurant_id;")
    res = cursor.fetchall()
    return res

# %%
def get_count():
    conn = pymysql.connect(host = "localhost",
                user= "root", password = "1234", charset = "utf8")
    cursor = conn.cursor()
    cursor.execute("select count(*) from young_cheline.evaluate group by menu_id;")
    g_menu_id = cursor.fetchall()

    cursor.execute('''SELECT menu_id, COUNT(CASE WHEN couple LIKE '0' THEN 1 END) AS specific_count
        FROM young_cheline.evaluate
        GROUP BY menu_id;''')
    
    couple = cursor.fetchall()
    
    cursor.execute('''SELECT menu_id, COUNT(CASE WHEN family LIKE '1' THEN 1 END) AS specific_count
        FROM young_cheline.evaluate
        GROUP BY menu_id;''')
    
    family = cursor.fetchall()

    cursor.execute('''SELECT menu_id, COUNT(CASE WHEN solo LIKE '2' THEN 1 END) AS specific_count
        FROM young_cheline.evaluate
        GROUP BY menu_id;''')
    
    solo = cursor.fetchall()

    cursor.execute('''SELECT menu_id, COUNT(CASE WHEN drink LIKE '3' THEN 1 END) AS specific_count
                    FROM young_cheline.evaluate
                    GROUP BY menu_id;''')
    
    drink = cursor.fetchall()

    cursor.execute('''SELECT menu_id, COUNT(CASE WHEN friend LIKE '4' THEN 1 END) AS specific_count
        FROM young_cheline.evaluate
        GROUP BY menu_id;''')
    
    friend = cursor.fetchall()

    cursor.execute('''SELECT menu_id, AVG(NULLIF(cleaning, '')),AVG(NULLIF(plating, '')),AVG(NULLIF(price, '')),AVG(NULLIF(service, ''))
        FROM young_cheline.evaluate
        GROUP BY menu_id;''')
    
    avg_exxtra = cursor.fetchall()

    eva = get_mean_taste()
    for menu_id in range(0, len(g_menu_id)):
        menu_count =g_menu_id[menu_id][0] #메뉴별 평가 갯수
        
        menu = eva[menu_id][0]
        restaurant_id = eva[menu_id][1]
        avg_taste = eva[menu_id][2]

        cleaning = avg_exxtra[menu_id][1]
        plating = avg_exxtra[menu_id][2]
        price = avg_exxtra[menu_id][3]
        service = avg_exxtra[menu_id][4]

        ## mood
        solo2 = 2 if  (solo[menu_id][1]/ menu_count) >0.8 else None
        couple0 = 0 if  (couple[menu_id][1]/ menu_count) >0.8 else None
        drink3 = 3 if  (drink[menu_id][1]/ menu_count) >0.8 else None
        family1 = 1 if  (family[menu_id][1]/ menu_count) >0.8 else None
        friend4 = 4 if  (friend[menu_id][1]/ menu_count) >0.8 else None

        cursor.execute('''INSERT INTO young_cheline.restaurant_evaluate
            (menu_id, cleaning, plating, price, restaurant_id, service, taste, couple, drink, family, friend, solo)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''',
                       (menu, cleaning, plating, price, restaurant_id, service, avg_taste, couple0, drink3, family1, friend4, solo2))

    
    conn.commit()

# %%
if __name__ == "__main__":
    res = get_count()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[60], line 2
#       1 if __name__ == "__main__":
# ----> 2     res = get_count()
#
# Cell In[59], line 44, in get_count()
#      38 cursor.execute('''SELECT menu_id, AVG(NULLIF(cleaning, '')),AVG(NULLIF(plating, '')),AVG(NULLIF(price, '')),AVG(NULLIF(service, ''))
#      39     FROM young_cheline.evaluate
#      40     GROUP BY menu_id;''')
#      42 avg_exxtra = cursor.fetchall()
# ---> 44 eva = get_mean_taste()
#      45 for menu_id in range(0, len(g_menu_id)):
#      46     menu_count =g_menu_id[menu_id][0] #메뉴별 평가 갯수
#
# Cell In[58], line 5, in get_mean_taste()
#       2 conn = pymysql.connect(host = "localhost",
#       3             user= "root", password = "1234", charset = "utf8")
#       4 cursor = conn.cursor()
# ----> 5 cursor.execute("select menu_id, restaurant_id,AVG(taste) from young_cheline.evaluate group by menu_id, restaurant_id;")
#       6 res = cursor.fetchall()
#       7 return res
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'taste' in 'field list'")

# %% [markdown]
# def Sample_Data_Random_Repeat(df,n):
#     DF = df
#     DF_num = len(DF)
#     ExtractionValues = []
#     for i in range(n):
#         random_index = random.randrange(DF_num)
#         extractionList = DF.iloc[random_index].to_list()
#         ExtractionValues.append(extractionList)
#     return ExtractionValues
#
# data = Sample_Data_Random_Repeat(Raw_df,5000)
#
# ExtractionDf = pd.DataFrame(data = data,columns=['EvaluationTime', 'Gender', 'RestaurantName', 'MenuName', 'Taste',
#                 'Plating', 'AmbienceDate','AmbienceFamily', 'AmbienceAlone', 'AmbienceAlcohol', 'AmbienceFriend',
#                 'Service', 'Cleanness', 'Cost'])
#
# ExtractionDf.to_csv('RandomRepeatData.csv')
#
# for i in range(len(NRS_df)):
#     row = NRS_df.iloc[i,0]
#     col = NRS_df.iloc[i,2]
#     val = NRS_df.iloc[i,1]
#     for j in range(len(row_list)):
#        if row == row_list[j]:
#            for k in range(len(col_list)):
#                if col == col_list[k]:
#                    user_history_df.iloc[j,k] = int(val)
#
# user_history_df
#
# colum = list(set(NRS_df.iloc[:,2].tolist()))
#
# menu_list = list(set(NRS_df.iloc[:,0].tolist()))
#
# user_history_df = pd.DataFrame(columns = colum, index = menu_list)
#
# row_list = user_history_df.index.tolist()
